# %%
from google.colab import drive

# %%
drive.mount('/gdrive')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     729             try:
# --> 730                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     731             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     465         """
# --> 466         parts = [self.recv(flags, copy=copy, track=track)]
#     467         # have first part already, only loop while more to receive
#
# ...

# %%
# %cd /gdrive
# Out:
# /gdrive

# %%
# !ls '/gdrive/My Drive/dataset'
# Out:
#  test.csv  'Test Images'   train.csv  'Train Images'

# %%
import cv2

# %%
# !ls '/gdrive/My Drive/dataset/Train Images'
# Out:
# image10000.jpg	image2245.jpg  image4339.jpg  image6371.jpg  image8240.jpg
# image10002.jpg	image2247.jpg  image433.jpg   image6372.jpg  image8243.jpg
# image10003.jpg	image2248.jpg  image4343.jpg  image6373.jpg  image8244.jpg
# image10004.jpg	image2249.jpg  image4347.jpg  image6375.jpg  image8246.jpg
# image10006.jpg	image2251.jpg  image4348.jpg  image6376.jpg  image8247.jpg
# image10007.jpg	image2254.jpg  image4349.jpg  image6377.jpg  image8248.jpg
# image10011.jpg	image2255.jpg  image4350.jpg  image6381.jpg  image8249.jpg
# image10013.jpg	image2257.jpg  image4351.jpg  image6382.jpg  image8250.jpg
# image10015.jpg	image2259.jpg  image4352.jpg  image6383.jpg  image8252.jpg
# image10016.jpg	image225.jpg   image4353.jpg  image6385.jpg  image8253.jpg
# image10017.jpg	image2260.jpg  image4356.jpg  image6386.jpg  image8255.jpg
# image10018.jpg	image2261.jpg  image4357.jpg  image6387.jpg  image8256.jpg
# image10019.jpg	image2262.jpg  image4358.jpg  image6388.jpg  image8258.jpg
# ...

# %%
import os
import matplotlib as plt
from PIL import ImageEnhance

# %%
os.listdir('/gdrive/My Drive/dataset/Train Images')
# Out:
# ['image8535.jpg',
#  'image8550.jpg',
#  'image8553.jpg',
#  'image8554.jpg',
#  'image8542.jpg',
#  'image8547.jpg',
#  'image854.jpg',
#  'image8540.jpg',
#  'image8536.jpg',
#  'image8555.jpg',
#  'image8557.jpg',
#  'image8571.jpg',
#  'image8559.jpg',
#  'image8574.jpg',
#  'image8568.jpg',
#  'image8562.jpg',
#  'image8560.jpg',
#  'image857.jpg',
#  'image8565.jpg',
#  'image8570.jpg',
#  'image8561.jpg',
#  'image8575.jpg',
#  'image858.jpg',
#  'image8576.jpg',
#  'image8580.jpg',
#  'image8582.jpg',
#  'image8583.jpg',
#  'image8581.jpg',
#  'image8588.jpg',
#  'image8585.jpg',
#  'image8589.jpg',
#  'image859.jpg',
#  'image8590.jpg',
#  'image8592.jpg',
#  'image8596.jpg',
#  'image8594.jpg',
#  'image8598.jpg',
#  'image86.jpg',
#  'image8602.jpg',
#  'image8608.jpg',
#  'image8606.jpg',
#  'image8605.jpg',
#  'image8597.jpg',
#  'image8609.jpg',
#  'image8611.jpg',
#  'image8614.jpg',
#  'image8627.jpg',
#  'image8618.jpg',
#  'image8616.jpg',
#  'image8621.jpg',
# ...

# %%
dir1='/gdrive/My Drive/dataset/Train Images'
l=[]
for i in os.listdir('/gdrive/My Drive/dataset/Train Images'):
  img=cv2.imread(dir1+'/'+i)
  img=img.resize((900,900))
  l.append(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3036d258f2dd> in <module>()
#       1 dir1='/gdrive/My Drive/dataset/Train Images'
#       2 l=[]
# ----> 3 for i in os.listdir('/gdrive/My Drive/dataset/Train Images'):
#       4   img=cv2.imread(dir1+'/'+i)
#       5   img=img.resize((900,900))
#
# NameError: name 'os' is not defined

# %%
dir1='/gdrive/My Drive/dataset/Train Images'
img=cv2.imread(dir1+'/'+'image9450.jpg',0)
plt.pyplot.imshow(img,cmap='gray')
scale=300
h=int(img.shape[0]*scale/100)
w=int(img.shape[1]*scale/100)
dim=(200,200)
img1=cv2.resize(img,dim)

# %%
plt.pyplot.imshow(img1)
th3 = f.apply(cv2.adaptiveThreshold(img1,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,11,2))
plt.pyplot.imshow(th3,cmap='gray')

# %%
# Out:
# None

# %%
img1.shape
# Out:
# (240, 321, 3)

# %%
import numpy as np
c=np.random.choice(os.listdir('/gdrive/My Drive/dataset/Train Images'))
img=cv2.imread(dir1+'/'+c,0)
plt.pyplot.imshow(img,cmap='gray')
dim=(900,900)
img1=cv2.resize(img,dim)
ret3,th3 = cv2.threshold(img1,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

plt.pyplot.imshow(th3,cmap='gray')
plt.pyplot.show()

# %%
#img=f.apply(img)
plt.pyplot.imshow(img1,cmap='gray')
c
# Out:
# 'image6157.jpg'

# %%
f=cv2.createBackgroundSubtractorMOG2()

# %%
from PIL import Image,ImageEnhance,ImageFilter

# %%
img=Image.open(dir1+'/'+'image3249.jpg')
img=img.resize((900,900))

# %%
img.filter(ImageFilter.GaussianBlur(10))
en=ImageEnhance.Sharpness(img)

# %%
img=en.enhance(5)
plt.pyplot.imshow(img)

# %%
ret3,th3 = cv2.threshold(img,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
plt.pyplot.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-227-6ff79a4629aa> in <module>()
# ----> 1 ret3,th3 = cv2.threshold(img,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
#       2 plt.pyplot.imshow(img)
#
# TypeError: Expected Ptr<cv::UMat> for argument '%s'
