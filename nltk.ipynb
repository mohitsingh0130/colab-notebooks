# %%
import nltk

# %%
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> 1
# Command '1' unrecognized
#
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> l
# Packages:
#   [ ] abc................. Australian Broadcasting Commission 2006
#   [ ] alpino.............. Alpino Dutch Treebank
#   [ ] averaged_perceptron_tagger Averaged Perceptron Tagger
#   [ ] averaged_perceptron_tagger_ru Averaged Perceptron Tagger (Russian)
#   [ ] basque_grammars..... Grammars for Basque
#   [ ] biocreative_ppi..... BioCreAtIvE (Critical Assessment of Information
# ...

# %%
import textblob

# %%
from textblob import TextBlob
data=TextBlob('hello everyone! hope you are enjoying machine learning.')

# %%
data.translate(to='gu')
# Out:
# TextBlob("બધાને નમસ્કાર! આશા છે કે તમે મશીન શિક્ષણનો આનંદ માણી રહ્યા છો.")

# %%
data=TextBlob('the movie was good.the cinematography was good')
data.sentiment
# Out:
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)

# %%
data=TextBlob('the havv two cars')
print(data.correct())
# Out:
# the have two cars

# %%
import string
import nltk
from nltk.corpus import stopwords

# %%
stopwords.words('english')[0:20]
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his']

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
_sentence='This is my first string test.wow! we are doing just fine'

# %%
no_punctuation=[char for char in test_sentence
                if char not in string.punctuation]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-3ac0a1749529> in <module>()
# ----> 1 no_punctuation=[char for char in test_sentence
#       2                 if char not in string.punctuation]
#
# NameError: name 'test_sentence' is not defined
